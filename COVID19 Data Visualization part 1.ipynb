# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %matplotlib inline

plt.style.use('fivethirtyeight')

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/datasets/covid-19/main/data/countries-aggregated.csv', parse_dates = ['Date'])
df1.head()
# Out:
#         Date      Country  Confirmed  Recovered  Deaths
# 0 2020-01-22  Afghanistan          0          0       0
# 1 2020-01-23  Afghanistan          0          0       0
# 2 2020-01-24  Afghanistan          0          0       0
# 3 2020-01-25  Afghanistan          0          0       0
# 4 2020-01-26  Afghanistan          0          0       0

# %%
df1['Total Cases'] = df1[['Confirmed','Recovered', 'Deaths']].sum(axis=1)
df1.head()
# Out:
#         Date      Country  Confirmed  Recovered  Deaths  Total Cases
# 0 2020-01-22  Afghanistan          0          0       0            0
# 1 2020-01-23  Afghanistan          0          0       0            0
# 2 2020-01-24  Afghanistan          0          0       0            0
# 3 2020-01-25  Afghanistan          0          0       0            0
# 4 2020-01-26  Afghanistan          0          0       0            0

# %% [markdown]
# ## Wordwide cases regarding COVID-19

# %%
worldwide_df = df1.groupby(['Date']).sum()
worldwide_df.head()
# Out:
#             Confirmed  Recovered  Deaths  Total Cases
# Date
# 2020-01-22        557         30      17          604
# 2020-01-23        655         32      18          705
# 2020-01-24        941         39      26         1006
# 2020-01-25       1433         42      42         1517
# 2020-01-26       2118         56      56         2230

# %%
plot1 = worldwide_df.plot(figsize=(16,10))
plot1.set_xlabel('Date')
plot1.set_ylabel('Number of Cases Worldwide')
plot1.title.set_text('Worldwide COVID Insights')

plt.show()

# %% [markdown]
# ### United States Daily Cases and Deaths

# %%
us_df = df1[df1['Country'] =='US'].groupby(['Date']).sum()

fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111)

ax.plot(worldwide_df[['Total Cases']], label='Worldwide')
ax.plot(us_df[['Total Cases']], label='USA')
ax.set_xlabel('Date')
ax.set_ylabel('Number of Cases Worldwide')
ax.title.set_text('Worldwide vs USA Total Cases')

plt.legend(loc='upper left')
plt.show()

# %%
us_df = us_df.reset_index()
us_df.head()
# Out:
#         Date  Confirmed  Recovered  Deaths  Total Cases
# 0 2020-01-22          1          0       0            1
# 1 2020-01-23          1          0       0            1
# 2 2020-01-24          2          0       0            2
# 3 2020-01-25          2          0       0            2
# 4 2020-01-26          5          0       0            5

# %%
us_df['Daily Confirmed'] = us_df['Confirmed'].sub(us_df['Confirmed'].shift())
us_df
# Out:
#           Date  Confirmed  Recovered  Deaths  Total Cases  Daily Confirmed
# 0   2020-01-22          1          0       0            1              NaN
# 1   2020-01-23          1          0       0            1              0.0
# 2   2020-01-24          2          0       0            2              1.0
# 3   2020-01-25          2          0       0            2              0.0
# 4   2020-01-26          5          0       0            5              3.0
# ..         ...        ...        ...     ...          ...              ...
# 525 2021-06-30   33664970          0  604714     34269684          12872.0
# 526 2021-07-01   33679433          0  605019     34284452          14463.0
# 527 2021-07-02   33709131          0  605413     34314544          29698.0
# 528 2021-07-03   33713870          0  605493     34319363           4739.0
# 529 2021-07-04   33717567          0  605526     34323093           3697.0
#
# [530 rows x 6 columns]

# %%
us_df['Daily Deaths'] = us_df['Deaths'].sub(us_df['Deaths'].shift())
us_df
# Out:
#           Date  Confirmed  Recovered  Deaths  Total Cases  Daily Confirmed  \
# 0   2020-01-22          1          0       0            1              NaN
# 1   2020-01-23          1          0       0            1              0.0
# 2   2020-01-24          2          0       0            2              1.0
# 3   2020-01-25          2          0       0            2              0.0
# 4   2020-01-26          5          0       0            5              3.0
# ..         ...        ...        ...     ...          ...              ...
# 525 2021-06-30   33664970          0  604714     34269684          12872.0
# 526 2021-07-01   33679433          0  605019     34284452          14463.0
# 527 2021-07-02   33709131          0  605413     34314544          29698.0
# 528 2021-07-03   33713870          0  605493     34319363           4739.0
# 529 2021-07-04   33717567          0  605526     34323093           3697.0
#
#      Daily Deaths
# 0             NaN
# 1             0.0
# ...

# %%
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(111)

ax.bar(us_df['Date'], us_df['Daily Confirmed'], color='b', label='US Daily Confirmed Cases')
ax.bar(us_df['Date'], us_df['Daily Deaths'], color='r', label='US Daily Deaths')
ax.set_xlabel('Date')
ax.set_ylabel('Number of People Affected')
ax.title.set_text('US Daily Cases and Deaths')

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Greece Daily Cases and Deaths

# %%
gr_df = df1[df1['Country'] =='Greece'].groupby(['Date']).sum()

fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111)

ax.plot(worldwide_df[['Total Cases']], label='Worldwide')
ax.plot(gr_df[['Total Cases']], label='Greece')
ax.set_xlabel('Date')
ax.set_ylabel('Number of Cases Worldwide')
ax.title.set_text('Worldwide vs Greece Total Cases')

plt.legend(loc='upper left')
plt.show()

# %%
gr_df = gr_df.reset_index()
gr_df.head()
# Out:
#         Date  Confirmed  Recovered  Deaths  Total Cases
# 0 2020-01-22          0          0       0            0
# 1 2020-01-23          0          0       0            0
# 2 2020-01-24          0          0       0            0
# 3 2020-01-25          0          0       0            0
# 4 2020-01-26          0          0       0            0

# %%
gr_df['Daily Confirmed'] = gr_df['Confirmed'].sub(gr_df['Confirmed'].shift())
gr_df
# Out:
#           Date  Confirmed  Recovered  Deaths  Total Cases  Daily Confirmed
# 0   2020-01-22          0          0       0            0              NaN
# 1   2020-01-23          0          0       0            0              0.0
# 2   2020-01-24          0          0       0            0              0.0
# 3   2020-01-25          0          0       0            0              0.0
# 4   2020-01-26          0          0       0            0              0.0
# ..         ...        ...        ...     ...          ...              ...
# 525 2021-06-30     422456      93764   12687       528907            627.0
# 526 2021-07-01     423185      93764   12691       529640            729.0
# 527 2021-07-02     424165      93764   12701       530630            980.0
# 528 2021-07-03     425347      93764   12710       531821           1182.0
# 529 2021-07-04     425964      93764   12716       532444            617.0
#
# [530 rows x 6 columns]

# %%
gr_df['Daily Deaths'] = gr_df['Deaths'].sub(gr_df['Deaths'].shift())
gr_df
# Out:
#           Date  Confirmed  Recovered  Deaths  Total Cases  Daily Confirmed  \
# 0   2020-01-22          0          0       0            0              NaN
# 1   2020-01-23          0          0       0            0              0.0
# 2   2020-01-24          0          0       0            0              0.0
# 3   2020-01-25          0          0       0            0              0.0
# 4   2020-01-26          0          0       0            0              0.0
# ..         ...        ...        ...     ...          ...              ...
# 525 2021-06-30     422456      93764   12687       528907            627.0
# 526 2021-07-01     423185      93764   12691       529640            729.0
# 527 2021-07-02     424165      93764   12701       530630            980.0
# 528 2021-07-03     425347      93764   12710       531821           1182.0
# 529 2021-07-04     425964      93764   12716       532444            617.0
#
#      Daily Deaths
# 0             NaN
# 1             0.0
# ...

# %%
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(111)

ax.bar(gr_df['Date'], gr_df['Daily Confirmed'], color='b', label='Greece Daily Confirmed Cases')
ax.bar(gr_df['Date'], gr_df['Daily Deaths'], color='r', label='Greeece Daily Deaths Cases')
ax.set_xlabel('Date')
ax.set_ylabel('Number of people affected')
ax.title.set_text('Greece Daily Cases and Deaths')


plt.legend(loc = 'upper left')
plt.show()
